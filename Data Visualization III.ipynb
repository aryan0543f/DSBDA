# %% [markdown]
# # Assignment No 10 : Data Visualization 3

# %% [markdown]
# ---

# %% [markdown]
# ## Importing Required Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %% [markdown]
# ## # Reading csv into Dataframe

# %%
df = pd.read_csv('Data Set/iris.csv')
df

# %% [markdown]
# ## # Data preprocessing

# %%
df.shape

# %%
df.columns

# %%
df.dtypes

# %%
df.info()

# %%
df.describe()

# %%
# Rename columns to standard names
df.columns = ['SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm', 'Species']
df

# %% [markdown]
# ## # Data Visualization

# %%
sns.histplot(df['SepalLengthCm'], kde=True)

# %%
sns.histplot(df['SepalWidthCm'], kde=True)

# %%
sns.histplot(df['PetalLengthCm'], kde=True)

# %%
sns.histplot(df['PetalWidthCm'], kde=True)

# %%
plt.hist(df['SepalLengthCm'])

# %%
plt.hist(df['SepalWidthCm'])

# %%
plt.hist(df['PetalLengthCm'])

# %%
plt.hist(df['PetalWidthCm'])

# %%
sns.boxplot(x=df['SepalLengthCm'])

# %%
sns.boxplot(x=df['SepalWidthCm'])

# %%
sns.boxplot(x=df['PetalLengthCm'])

# %%
sns.boxplot(x=df['PetalWidthCm'])

# %%
sns.boxplot(data = df, x = df['SepalLengthCm'], y = df['Species'])

# %%
sns.boxplot(data = df, x = df['Species'], y = df['SepalWidthCm'])

# %%
sns.boxplot(data = df, x = df['Species'], y = df['PetalWidthCm'])

# %%
sns.boxplot(data = df, x = df['Species'], y = df['PetalLengthCm'])

# %%
# =============================================================================\n',
        # IMPORTANT NOTES FOR ORAL EXAM - DATA VISUALIZATION III\n',
        # HISTOGRAMS AND BOXPLOTS ON IRIS DATASET\n',
        # =============================================================================\n',
        #\n',
        # --------------------------------------------------------------------------\n',
        # WHAT IS THIS PRACTICAL ABOUT?\n',
        # --------------------------------------------------------------------------\n',
        # This practical focuses on visualizing the distribution of features in the\n',
        # Iris dataset using histograms and boxplots.\n',
        # We use both matplotlib and seaborn to create these plots.\n',
        # The goal is to understand how each measurement (sepal/petal length/width)\n',
        # is distributed and how it differs across the 3 flower species.\n',
        #\n',
        # --------------------------------------------------------------------------\n',
        # DATASET USED - IRIS DATASET\n',
        # --------------------------------------------------------------------------\n',
        # 150 rows x 5 columns. 3 species: Iris-setosa, Iris-versicolor, Iris-virginica.\n',
        #\n',
        # Columns (after renaming):\n',
        #   SepalLengthCm : Length of sepal in cm\n',
        #   SepalWidthCm  : Width of sepal in cm\n',
        #   PetalLengthCm : Length of petal in cm\n',
        #   PetalWidthCm  : Width of petal in cm\n',
        #   Species       : Type of flower (categorical)\n',
        #\n',
        # No missing values in this dataset.\n',
        #\n',
        # --------------------------------------------------------------------------\n',
        # LIBRARIES USED\n',
        # --------------------------------------------------------------------------\n',
        # pandas (pd)       : For loading and managing data.\n',
        # numpy  (np)       : For numerical operations.\n',
        # matplotlib.pyplot : For basic plots like plt.hist().\n',
        # seaborn (sns)     : For advanced plots like sns.histplot() and sns.boxplot().\n',
        # %matplotlib inline: Shows plots inside the Jupyter notebook.\n',
       # \n',
        # --------------------------------------------------------------------------\n',
        # DATA PREPROCESSING\n',
        # --------------------------------------------------------------------------\n',
        # df.shape          : (150, 5) - 150 rows, 5 columns.\n',
        # df.columns        : Shows original column names.\n',
        # df.dtypes         : 4 float columns + 1 object (Species).\n',
        # df.info()         : Summary of DataFrame.\n',
        # df.describe()     : Statistics for numerical columns.\n',
        # df.columns = [...]: Renames columns to standard readable names.\n',
        #\n',
        # --------------------------------------------------------------------------\n',
        # PLOTS USED IN THIS PRACTICAL\n',
        # --------------------------------------------------------------------------\n',
        #\n',
        # 1. sns.histplot() - Seaborn Histogram with KDE\n',
        #    sns.histplot(df[\"SepalLengthCm\"], kde=True)\n',
        #    sns.histplot(df[\"SepalWidthCm\"],  kde=True)\n',
        #    sns.histplot(df[\"PetalLengthCm\"], kde=True)\n',
        #    sns.histplot(df[\"PetalWidthCm\"],  kde=True)\n',
        #\n',
        #    - Shows the frequency distribution of a single numerical column.\n',
        #    - Bars (histogram) show how many values fall in each range.\n',
        #    - kde=True : Adds a smooth KDE (Kernel Density Estimate) curve on top.\n',
        #    - KDE is a smooth line that estimates the probability distribution.\n',
        #    - Done for all 4 measurement columns to see their distributions.\n',
        #    - Helps answer: Is the data normally distributed? Is it skewed?\n',
        #\n',
        #    NOTE: sns.histplot() is the modern replacement for sns.distplot()\n',
        #    (distplot is deprecated in newer versions of seaborn).\n',
        #\n',
        # 2. plt.hist() - Matplotlib Histogram (Basic)\n',
        #    plt.hist(df[\"SepalLengthCm\"])\n',
        #    plt.hist(df[\"SepalWidthCm\"])\n',
        #    plt.hist(df[\"PetalLengthCm\"])\n',
        #    plt.hist(df[\"PetalWidthCm\"])\n',
        #\n',
        #    - Basic histogram using matplotlib (no KDE curve).\n',
        #    - Shows the same frequency distribution as sns.histplot() but simpler.\n',
        #    - Done for all 4 measurement columns.\n',
        #\n',
        #    DIFFERENCE BETWEEN sns.histplot() AND plt.hist():\n',
        #      plt.hist()     : Basic matplotlib histogram. Simple, no KDE.\n',
        #      sns.histplot() : Seaborn histogram. More features (kde=True, color, etc.).\n',
        #                       Better looking and easier to customize.\n',
        #\n',
        # 3. sns.boxplot() - Box Plot (Single Variable)\n',
        #    sns.boxplot(x=df[\"SepalLengthCm\"])\n',
        #    sns.boxplot(x=df[\"SepalWidthCm\"])\n',
        #    sns.boxplot(x=df[\"PetalLengthCm\"])\n',
        #    sns.boxplot(x=df[\"PetalWidthCm\"])\n',
        #\n',
        #    - Shows the distribution of a single numerical column.\n',
        #    - The box shows: Q1 (25%), median (50%), Q3 (75%).\n',
        #    - Whiskers extend to min and max within 1.5 * IQR.\n',
        #    - Dots beyond whiskers = OUTLIERS.\n',
        #    - x= means the variable is plotted on the horizontal axis.\n',
        #    - Done for all 4 measurement columns.\n',
        #\n',
        # 4. sns.boxplot() - Box Plot (By Species)\n',
        #    sns.boxplot(data=df, x=df[\"SepalLengthCm\"], y=df[\"Species\"])\n',
        #    sns.boxplot(data=df, x=df[\"Species\"],       y=df[\"SepalWidthCm\"])\n',
        #    sns.boxplot(data=df, x=df[\"Species\"],       y=df[\"PetalWidthCm\"])\n',
        #    sns.boxplot(data=df, x=df[\"Species\"],       y=df[\"PetalLengthCm\"])\n',
        #\n',
        #    - Shows the distribution of a measurement for EACH species separately.\n',
        #    - Creates one box per species, side by side for easy comparison.\n',
        #    - Helps see: Which species has the largest/smallest petals or sepals?\n',
        #    - x=Species, y=measurement : Species on x-axis, measurement on y-axis.\n',
        #    - x=measurement, y=Species : Measurement on x-axis, Species on y-axis (horizontal boxes).\n',
        #\n',
        #    KEY INSIGHT FROM BOXPLOTS:\n',
        #      - Iris-setosa has the smallest petal length and width.\n',
        #      - Iris-virginica has the largest petal length and width.\n',
        #      - Petal measurements separate the 3 species better than sepal measurements.\n',
        #\n',
        # --------------------------------------------------------------------------\n',
        # WHAT DOES A BOXPLOT SHOW? (Detailed)\n',
        # --------------------------------------------------------------------------\n',
        #\n',
        #   |----[  Q1 | Median | Q3  ]----|\n',
        #   min  whisker  box        whisker  max\n',
        #                                         o  <- outlier\n',
        #\n',
        #   - Box      : Contains the middle 50% of data (from Q1 to Q3).\n',
        #   - Median   : Line inside the box (50th percentile).\n',
        #   - Q1       : 25th percentile (lower edge of box).\n',
        #   - Q3       : 75th percentile (upper edge of box).\n',
        #   - IQR      : Q3 - Q1 (height/width of the box).\n',
        #   - Whiskers : Extend to Q1 - 1.5*IQR and Q3 + 1.5*IQR.\n',
        #   - Outliers : Points beyond the whiskers (shown as dots).\n',
        #\n',
        # --------------------------------------------------------------------------\n',
        # SUMMARY TABLE - ALL PLOTS\n',
        # --------------------------------------------------------------------------\n',
        # | Plot              | Function           | What it shows                       |\n',
        # |-------------------|--------------------|-------------------------------------|\n',
        # | Seaborn Histogram | sns.histplot()     | Distribution with optional KDE      |\n',
        # | Matplotlib Hist   | plt.hist()         | Basic frequency histogram           |\n',
        # | Boxplot (single)  | sns.boxplot(x=col) | Distribution of one column          |\n',
        # | Boxplot (grouped) | sns.boxplot(x,y)   | Distribution per species/category   |\n',
        #\n',
        # --------------------------------------------------------------------------\n',
        # KEY TERMS TO REMEMBER\n',
        # --------------------------------------------------------------------------\n',
        # Histogram       : Bar chart showing frequency of values in ranges (bins).\n',
        # KDE             : Kernel Density Estimate - smooth curve over histogram.\n',
        # kde=True        : Adds KDE curve to sns.histplot().\n',
        # Boxplot         : Shows Q1, median, Q3, whiskers, and outliers.\n',
        # Q1              : 25th percentile (lower quartile).\n',
        # Q2 / Median     : 50th percentile (middle value).\n',
        # Q3              : 75th percentile (upper quartile).\n',
        # IQR             : Interquartile Range = Q3 - Q1.\n',
        # Whisker         : Extends to Q1 - 1.5*IQR and Q3 + 1.5*IQR.\n',
        # Outlier         : Data point beyond the whiskers (shown as a dot).\n',
        # Distribution    : How data values are spread across a range.\n',
        # Skewed          : Distribution that is not symmetric (leans left or right).\n',
        # Normal dist.    : Bell-shaped, symmetric distribution.\n',
        #\n',
        # --------------------------------------------------------------------------\n',
        # POSSIBLE ORAL EXAM QUESTIONS AND ANSWERS\n',
        # --------------------------------------------------------------------------\n',
        # Q: What is this practical about?\n',
        # A: Visualizing the distribution of Iris flower measurements (sepal and petal\n',
        #    length/width) using histograms and boxplots, both overall and per species.\n',
        #\n',
        # Q: What is the difference between sns.histplot() and plt.hist()?\n',
        # A: plt.hist() is a basic matplotlib histogram with no extra features.\n',
        #    sns.histplot() is a seaborn histogram with more options like kde=True\n',
        #    to add a smooth KDE curve, better styling, and easier customization.\n',
        #\n',
        # Q: What does kde=True do in sns.histplot()?\n',
        # A: It adds a KDE (Kernel Density Estimate) curve on top of the histogram.\n',
        #    KDE is a smooth line that estimates the probability distribution of the data.\n',
        #\n',
        # Q: What does a boxplot show?\n',
        # A: A boxplot shows the distribution of a numerical variable:\n',
        #    - Box: Q1 (25%), median (50%), Q3 (75%)\n',
        #    - Whiskers: min and max within 1.5*IQR\n',
        #    - Dots: outliers beyond the whiskers\n',
        #\n',
        # Q: What is IQR?\n',
        # A: IQR = Interquartile Range = Q3 - Q1.\n',
        #    It measures the spread of the middle 50% of data.\n',
        #   Whiskers in a boxplot extend to Q1 - 1.5*IQR and Q3 + 1.5*IQR.\n',
        #\n',
        # Q: What is the difference between a single boxplot and a grouped boxplot?\n',
        # A: Single boxplot (sns.boxplot(x=col)) shows distribution of one column overall.\n',
        #  Grouped boxplot (sns.boxplot(x=Species, y=col)) shows distribution\n',
        #    of a column separately for each species, side by side for comparison.\n',
        #\n',
        # Q: What insight do the boxplots give about the Iris species?\n',
        # A: Iris-setosa has the smallest petal length and width.\n',
        #    Iris-virginica has the largest petal length and width.\n',
        #    Petal measurements separate the 3 species more clearly than sepal measurements.\n',
        #\n',
        # Q: What is the difference between a histogram and a boxplot?\n',
        # A: Histogram shows the frequency of values in ranges (bins) as bars.\n',
        #    It shows the shape of the distribution (normal, skewed, etc.).\n',
        #    Boxplot shows Q1, median, Q3, whiskers, and outliers.\n',
        #    It is better for comparing distributions across categories.\n',
        #\n',
        # Q: Why do we rename the columns?\n',
        # A: The original column names may be unclear or inconsistent.\n',
        #    Renaming to SepalLengthCm, SepalWidthCm, etc. makes them more readable\n',
        #    and easier to use in plot labels.\n',
        # =============================================================================\n',
        #print(\"Oral Exam Notes Loaded Successfully!\")'
